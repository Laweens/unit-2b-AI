# %%
import gpt_2_simple as gpt2

session =gpt2.start_tf_sess()
gpt2.finetune(
    session,"Steam_questions.txt", model_name="124M", steps= 20, run_name= 'steam'
)
# Out:
# 2023-12-22 09:59:54.267134: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:388] MLIR V1 optimization pass is not enabled
# Loading checkpoint checkpoint/steam/model-2
# INFO:tensorflow:Restoring parameters from checkpoint/steam/model-2
# Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00, 1447.31it/s]
# dataset has 2195 tokens
# Training...
# [3 | 18.98] loss=2.69 avg=2.69
# [4 | 40.25] loss=2.38 avg=2.54
# [5 | 60.33] loss=2.05 avg=2.37
# [6 | 79.96] loss=1.70 avg=2.20
# [7 | 100.06] loss=1.44 avg=2.04
# [8 | 119.76] loss=1.35 avg=1.93
# interrupted
# Saving checkpoint/steam/model-8

# %%
gpt2.generate(session, prefix ='How does this impact my high school graduation requirements?')

# %%
gpt2.generate(session, prefix='Explain the smaller work-based learning opportunities I can get involved with.')

# %%
gpt2.generate(session, prefix ='How/When do I decide which CTE pathway I want to study? Can I choose more than one?')
# Out:
# 2023-12-20 09:14:43.501338: W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at resource_variable_ops.cc:721 : NOT_FOUND: Container localhost does not exist. (Could not find resource: localhost/model/wte)
# 2023-12-20 09:14:43.501359: W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at resource_variable_ops.cc:721 : NOT_FOUND: Container localhost does not exist. (Could not find resource: localhost/model/wpe)
# 2023-12-20 09:14:43.501744: W tensorflow/core/framework/op_kernel.cc:1839] OP_REQUIRES failed at resource_variable_ops.cc:721 : NOT_FOUND: Container localhost does not exist. (Could not find resource: localhost/model/wte)
# ---------------------------------------------------------------------------
# FailedPreconditionError                   Traceback (most recent call last)
# File ~/Library/Python/3.10/lib/python/site-packages/tensorflow/python/client/session.py:1402, in BaseSession._do_call(self, fn, *args)
#    1401 try:
# ...
